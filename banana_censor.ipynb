# %% [markdown]
# <a href="https://colab.research.google.com/github/Olubusolami-R/banana-censor/blob/main/banana_censor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
import os

# 1. Mount Drive
drive.mount('/content/drive')

# 2. Change Directory to your repo
# NOTE: Make sure this path matches exactly where you moved the file
repo_path = '/content/drive/MyDrive/code-projects/banana-censor'

# %cd $repo_path

# 3. Verify you are in the right place
print("I am currently working in:", os.getcwd())
# !ls  # This lists all files. You should see '.git' and your notebook name here.
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/code-projects/banana-censor
# I am currently working in: /content/drive/MyDrive/code-projects/banana-censor
# banana-censor.ipynb  README.md
